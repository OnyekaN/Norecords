# %%
from eyed3 import id3

# %%
from mutagen.id3 import ID3
from mutagen.easyid3 import EasyID3
from mutagen import File

# %%
import os
import sys

path = "/Users/OGN/Music/iTunes/iTunes Music/Music/"
music_dict = dict()
music_lib = []

# collect all artist directories
artist_dirs = [ os.path.join(path, i) for i in os.listdir(path) 
               if os.path.isdir(os.path.join(path, i))]

# list album directories within artist directories
for at in os.listdir(path):
    at_path = os.path.join(path, at)
    if os.path.isdir(at_path):
        # build small dict object with artist name and path to artist directory
        artist_dict = {
            "ARTIST_NAME": at,
            "ARTIST_PATH": at_path
        }  
        # build dict of artsits with key = artist name, value = artist directory path
        music_dict[at] = dict()
        music_dict[at]["ARTIST_PATH"] = at_path
        # alternative data structure: array of artist_dicts instead of dict of artist
        music_lib.append(artist_dict)
        # music_lib is what I end up using primarily
        
music_dict
# Out:
# {'1995': {'ARTIST_PATH': '/Users/OGN/Music/iTunes/iTunes Music/Music/1995'},
#  '2Pac': {'ARTIST_PATH': '/Users/OGN/Music/iTunes/iTunes Music/Music/2Pac'},
#  '3 Chairs': {'ARTIST_PATH': '/Users/OGN/Music/iTunes/iTunes Music/Music/3 Chairs'},
#  '311': {'ARTIST_PATH': '/Users/OGN/Music/iTunes/iTunes Music/Music/311'},
#  'A Silver Mt. Zion': {'ARTIST_PATH': '/Users/OGN/Music/iTunes/iTunes Music/Music/A Silver Mt. Zion'},
#  'A Tribe Called Quest': {'ARTIST_PATH': '/Users/OGN/Music/iTunes/iTunes Music/Music/A Tribe Called Quest'},
#  'ANOHNI': {'ARTIST_PATH': '/Users/OGN/Music/iTunes/iTunes Music/Music/ANOHNI'},
#  'AYBEE and Afrikan Sciences': {'ARTIST_PATH': '/Users/OGN/Music/iTunes/iTunes Music/Music/AYBEE and Afrikan Sciences'},
#  'Ab-Soul': {'ARTIST_PATH': '/Users/OGN/Music/iTunes/iTunes Music/Music/Ab-Soul'},
#  'AbJo': {'ARTIST_PATH': '/Users/OGN/Music/iTunes/iTunes Music/Music/AbJo'},
# ...

# %%
# for each artist directory, list all album subdirectories
for key, value in music_dict.iteritems():
    album_dir = [a for a in os.listdir(value["ARTIST_PATH"]) 
                 if os.path.isdir(os.path.join(value["ARTIST_PATH"], a))]
    music_dict[key]["ALBUMS"] = []
    for album in album_dir:
        # create small dict object with name of album and path to album subdirectory
        album_dict = {
            "ALBUM_NAME": album,
            "ALBUM_PATH": os.path.join(value["ARTIST_PATH"], album)
        }
        # append albums_dict to each artist in the music_dict
        music_dict[key]["ALBUMS"].append(album_dict)
        
# music_dict[artist] = {artist_path: path, albums: [{album_name:album_name, album_path:album path}]}
print music_dict["Christian Scott"]["ALBUMS"]            
# this data structure is made obsolete by music_lib below
# Out:
# [{'ALBUM_NAME': 'Rewind That', 'ALBUM_PATH': '/Users/OGN/Music/iTunes/iTunes Music/Music/Christian Scott/Rewind That'}, {'ALBUM_NAME': 'Yesterday You Said Tomorrow', 'ALBUM_PATH': '/Users/OGN/Music/iTunes/iTunes Music/Music/Christian Scott/Yesterday You Said Tomorrow'}]

# %%
# for each artist directory list all album subdirectories
for artist in music_lib:
    album_dirs = [al for al in os.listdir(artist["ARTIST_PATH"])
                if os.path.isdir(os.path.join(artist["ARTIST_PATH"], al))]
    # add albums array placeholder to artist dict
    artist["ALBUMS"] = []
    # for each album subdirectory create album dict with album name and path
    for album in album_dirs:
        album_dict = {
            "ALBUM_NAME": album,
            "ALBUM_PATH": os.path.join(artist["ARTIST_PATH"], album)
        }
        # append album dict to artist's albums array
        artist["ALBUMS"].append(album_dict)

# music_lib[artist_index] = {artist: path, albums = albums[album_index]}
print music_lib[0]["ALBUMS"][0]["ALBUM_PATH"]
# Out:
# /Users/OGN/Music/iTunes/iTunes Music/Music/1995/La Source

# %%
albums_dict = dict()
for artist in music_lib:
    for album in artist["ALBUMS"]:
        songs = [s for s in os.listdir(album["ALBUM_PATH"]) 
                 if "STORE" not in s] 
        try:
            first_song_path = "{}/{}".format(album["ALBUM_PATH"], songs[0])
        except Exception, e:
            print repr(e)
        new_image_path = "/Users/OGN/1Projects/norecords/app/assets/images/album art/{} - {}.jpg".format(
                        artist["ARTIST_NAME"], album["ALBUM_NAME"])
        file = File(first_song_path)
        try:
            artwork = file.tags["APIC:"].data
            with open(new_image_path, 'wb') as img:
                img.write(artwork)
            image_path = "/images/album art/{} - {}.jpg".format(
                        artist["ARTIST_NAME"], album["ALBUM_NAME"])
        except Exception, e:
            #print repr(e), song_image_path
            image_path = 'N/A'      
            
        songs = [song.replace('.mp3', '') for song in songs]
        songs = [song.replace('.m4a', '') for song in songs]
        
        albums_dict[album["ALBUM_NAME"]] = {
            "NAME": album["ALBUM_NAME"],
            "PATH": album["ALBUM_PATH"],
            "ARTIST": artist["ARTIST_NAME"],
            "SONGS": songs,
            "IMAGE_PATH": image_path
        }
#print albums_dict
# Out:
# IndexError('list index out of range',)
# IndexError('list index out of range',)
# IndexError('list index out of range',)

# %%
import pandas as pd

# %%
df = pd.DataFrame(albums_dict)
df = df.T
df
# Out:
#                                                            ARTIST  \
# #3                                            Finalzinho Chegando
# #4                                            Finalzinho Chegando
# 'Nard                                              Bernard Wright
# 'Round About Midnight                                 Miles Davis
# (Pronounced 'Lĕh-'nérd 'Skin-'nérd)             Lynyrd Skynyrd
# 0181                                                     Four Tet
# 08-09                                              Repeat Pattern
# 10 + 2_ 12 American Text Sound Pieces                Compilations
# 13.0.0.0.0                                                   TTNG
# 154                                                          Wire
# 1983                                                 Flying Lotus
# 1984                                                  Hugh Hopper
# 1999                                                  Joey Bada$$
# ...

# %%
import psycopg2

# %%
conn = psycopg2.connect(dbname='norecordsdb', user='gqe', host='localhost', password='')
cursor = conn.cursor()

# %%
create_table_sql = (
                'CREATE TABLE nrtable ('
                'id serial PRIMARY KEY,'
                'album text NOT NULL,'
                'artist text NOT NULL,'
                'songs text[] NOT NULL,'
                'artwork_path text NOT NULL);'
                )
    
#cursor.execute(create_table_sql)

# %%
cursor.execute("SELECT * FROM nrtable;")
for cur in cursor:
    print cur
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-13-57487d93c989> in <module>()
#       1
# ----> 2 cursor.execute("SELECT * FROM nrtable;")
#       3 for cur in cursor:
#       4     print cur
#
# ProgrammingError: relation "nrtable" does not exist
# LINE 1: SELECT * FROM nrtable;
#                       ^

# %%
"""
for key, value in albums_dict.iteritems():
    insert_sql = ('INSERT INTO nrtable '
                  '(album, artist, songs, artwork_path) '
                  'VALUES ("{0}", "{1}", "{2}", "{3}");'.format(
                   value["NAME"], value["ARTIST"], value["SONGS"], value["IMAGE_PATH"])
                )
    print insert_sql
    
    cursor.execute(insert_sql)
"""
# Out:
# '\nfor key, value in albums_dict.iteritems():\n    insert_sql = (\'INSERT INTO nrtable \'\n                  \'(album, artist, songs, artwork_path) \'\n                  \'VALUES ("{0}", "{1}", "{2}", "{3}");\'.format(\n                   value["NAME"], value["ARTIST"], value["SONGS"], value["IMAGE_PATH"])\n                )\n    print insert_sql\n    \n    cursor.execute(insert_sql)\n'

# %%
import requests
from bs4 import BeautifulSoup
import re

# %%
base = "https://www.youtube.com/results?search_query="
q = ['2Pac+all+eyez+on+me']
page = "&page="
count = 1

# %%
for query in q:
    scrapeUrl = base+str(query)+page+str(count)
    print "Scraping %s\n" % scrapeUrl
    r = requests.get(scrapeUrl)
    soup = BeautifulSoup(r.text)

    titles = soup.find_all("h3", class_="yt-lockup-title")
    print titles[0].a["href"]
# Out:
# Scraping https://www.youtube.com/results?search_query=2Pac+all+eyez+on+me&page=1
#
# /watch?v=05PCmqjIeNE
# /Users/OGN/anaconda/lib/python2.7/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 174 of the file /Users/OGN/anaconda/lib/python2.7/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))

# %%
import pickle

# %%
albums_dict_list = []
print len(albums_dict.keys())
# Out:
# 1684

# %%
for key, value in albums_dict.iteritems():
    albums_dict_list.append(value)  
print albums_dict_list[20:30][3]["PATH"]
print len(albums_dict_list)
# Out:
# /Users/OGN/Music/iTunes/iTunes Music/Music/nOvaslim/nOvaslim
# 1684

# %%
#for key, value in albums_dict.iteritems():
for value in albums_dict_list[1682:1684]:
        songs_dicts = [] 
        print value["NAME"]
        for song in value["SONGS"]:
            s_title = song.split()
            match = re.search("[0-9]+", s_title[0])
            if match:
                s_title.remove(s_title[0])
            full_title = value["ARTIST"].split() + s_title
            title_query = ""
            words_left = len(full_title)
            for f in full_title:
                words_left -= 1
                title_query += f
                if words_left > 0:
                    title_query += "+"
            scrapeUrl = base+str(title_query)+page+str()
            r = requests.get(scrapeUrl)
            soup = BeautifulSoup(r.text)
            titles = soup.find_all("h3", class_="yt-lockup-title")
            try:
                youtube_link = "https://youtube.com{}".format(titles[0].a["href"])
                print song, youtube_link
                song_dict = {"TITLE": song, "YT_LINK": youtube_link}
                songs_dicts.append(song_dict)
            except Exception, e:
                print repr(e)
                song_dict = {"TITLE": song, "YT_LINK": 'N/A'}
                songs_dicts.append(song_dict)
            
        value["SONGS_D"] = songs_dicts
# Out:
# Amplifier Worship
# 01 Huge https://youtube.com/watch?v=pNZX0Lz-Iuk
# 02 Ganbou-Ki https://youtube.com/watch?v=sTA5m7NIG_g
# 03 Hama https://youtube.com/watch?v=HavNkl8izMo
# 04 Kuruimizu https://youtube.com/watch?v=TGE3uagkO5o
# 05 Vomitself https://youtube.com/watch?v=SBwK2s734DQ
# Super Fly
# 01 Little Child Runnin' Wild https://youtube.com/watch?v=HJkjVfOcIxs
# 02 Pusherman https://youtube.com/watch?v=hCDAfa-NI-M
# 03 Freddie's Dead https://youtube.com/watch?v=0B6TKClPFQA
# 04 Junkie Chase (Instrumental) https://youtube.com/watch?v=UeoncoNuwMU
# 05 Give Me Your Love (Love Song) https://youtube.com/watch?v=dMGY8A1uHSM
# 06 Eddie You Should Know Better https://youtube.com/watch?v=ve276QabwPM
# 07 No Thing on Me (Cocaine Song) https://youtube.com/watch?v=O3RACWJ5hWo
# 08 Think (Instrumental) https://youtube.com/watch?v=GAZ9zBLLuOc
# 09 Superfly https://youtube.com/watch?v=-cmo6MRYf5g

# %%
#print albums_dict_list
pickle.dump(albums_dict_list, open("albumsDictList.p", "wb"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-19a14f2e0ca3> in <module>()
#       1 #print albums_dict_list
# ----> 2 pickle.dump(albums_dict_list, open("albumsDictList.p", "wb"))
#
# NameError: name 'albums_dict_list' is not defined

# %%
albums_dict_list = pickle.load(open("./albumsDictList.p", "rb"))

# %%
print albums_dict_list[1683]
# Out:
# {'IMAGE_PATH': '/images/album art/Curtis Mayfield - Super Fly', 'NAME': 'Super Fly', 'ARTIST': 'Curtis Mayfield', 'SONGS_D': [{'YT_LINK': 'https://youtube.com/watch?v=HJkjVfOcIxs', 'TITLE': "01 Little Child Runnin' Wild"}, {'YT_LINK': 'https://youtube.com/watch?v=hCDAfa-NI-M', 'TITLE': '02 Pusherman'}, {'YT_LINK': 'https://youtube.com/watch?v=0B6TKClPFQA', 'TITLE': "03 Freddie's Dead"}, {'YT_LINK': 'https://youtube.com/watch?v=UeoncoNuwMU', 'TITLE': '04 Junkie Chase (Instrumental)'}, {'YT_LINK': 'https://youtube.com/watch?v=dMGY8A1uHSM', 'TITLE': '05 Give Me Your Love (Love Song)'}, {'YT_LINK': 'https://youtube.com/watch?v=ve276QabwPM', 'TITLE': '06 Eddie You Should Know Better'}, {'YT_LINK': 'https://youtube.com/watch?v=O3RACWJ5hWo', 'TITLE': '07 No Thing on Me (Cocaine Song)'}, {'YT_LINK': 'https://youtube.com/watch?v=GAZ9zBLLuOc', 'TITLE': '08 Think (Instrumental)'}, {'YT_LINK': 'https://youtube.com/watch?v=-cmo6MRYf5g', 'TITLE': '09 Superfly'}], 'PATH': '/Users/OGN/Music/iTunes/i
# ...

# %%
for album in albums_dict_list[0:10]:
    for song in album["SONGS_D"]:
        print album["ARTIST"], ",", album["NAME"], ",", song["TITLE"], song["YT_LINK"]
    print album
# Out:
# The Shins , Chutes Too Narrow , 01 Kissing the Lipless https://youtube.com/watch?v=FMzKgB1cf24
# The Shins , Chutes Too Narrow , 02 Mine's Not a High Horse https://youtube.com/watch?v=CyqFhKpdNs0
# The Shins , Chutes Too Narrow , 03 So Says I https://youtube.com/watch?v=K-P15e6NvtU
# The Shins , Chutes Too Narrow , 04 Young Pilgrims https://youtube.com/watch?v=uW3Z1W8n2Dw
# The Shins , Chutes Too Narrow , 05 Saint Simon https://youtube.com/watch?v=jqYMRcnLU0o
# The Shins , Chutes Too Narrow , 06 Fighting in a Sack https://youtube.com/watch?v=FheM_qDwg6M
# The Shins , Chutes Too Narrow , 07 Pink Bullets https://youtube.com/watch?v=3XBabozrPGA
# The Shins , Chutes Too Narrow , 08 Turn a Square https://youtube.com/watch?v=d7yiT5phQgQ
# The Shins , Chutes Too Narrow , 09 Gone for Good https://youtube.com/watch?v=l10DWZTXGN4
# The Shins , Chutes Too Narrow , 10 Those to Come https://youtube.com/watch?v=SVsX56BPrpU
# ...

# %%
import psycopg2

# %%
conn = psycopg2.connect(dbname='norecordsdb', user='gqe', host='localhost', password='')
cursor = conn.cursor()

# %%
create_table_sql = (
                'CREATE TABLE songs ('
                'song_id serial PRIMARY KEY,'
                'song_name text NOT NULL,'
                'artist text NOT NULL,'
                'album text NOT NULL,'
                'youtube_link text NOT NULL,'
                'artwork_path text NOT NULL);'
                )

# %%
cursor.execute(create_table_sql)

# %%
cursor.close()
conn.commit()

# %%
conn = psycopg2.connect(dbname='norecordsdb', user='gqe', host='localhost', password='')
cursor = conn.cursor()

# %%
for album in albums_dict_list[34:]:
    for song in album["SONGS_D"]:
        insertSQL = ("INSERT INTO songs (song_id, song_name, artist, album, youtube_link, artwork_path) VALUES (%i, '%s', '%s', '%s', '%s', '%s');" 
                     % (song["id"], song["TITLE"].replace("'", "''"), album["ARTIST"].replace("'", "''"), album["NAME"].replace("'","''"), song["YT_LINK"], album["IMAGE_PATH"].replace("'", "''")) )
        print insertSQL
        try:
            conn = psycopg2.connect(dbname='norecordsdb', user='gqe', host='localhost', password='')
            cursor = conn.cursor()
            cursor.execute(insertSQL)
            conn.commit()
        except Exception, e:
            print repr(e)
# Out:
# INSERT INTO songs (song_id, song_name, artist, album, youtube_link, artwork_path) VALUES (318, '01 Spirals', 'Afrikan Sciences', 'Means and Ways', 'https://youtube.com/watch?v=fMThIYcUsSE', '/images/album art/Afrikan Sciences - Means and Ways');
# IntegrityError('duplicate key value violates unique constraint "songs_pkey"\nDETAIL:  Key (song_id)=(318) already exists.\n',)
# INSERT INTO songs (song_id, song_name, artist, album, youtube_link, artwork_path) VALUES (319, '02 A Tonk', 'Afrikan Sciences', 'Means and Ways', 'https://youtube.com/watch?v=1alKE8ayb80', '/images/album art/Afrikan Sciences - Means and Ways');
# IntegrityError('duplicate key value violates unique constraint "songs_pkey"\nDETAIL:  Key (song_id)=(319) already exists.\n',)
# ...

# %%
cursor.close()
conn.commit()
